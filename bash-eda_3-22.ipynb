# %%
# -------- Initial Exploration -------- #
"""bash
python -c "
import pandas as pd
df = pd.read_csv('EQI_2011_2015_PLACES_2020_merged.csv')
print('Shape:', df.shape)
print('\nColumns:', df.columns.tolist())
print('\nFirst few rows:')
print(df.head(2))
print('\nMissing values:')
print(df.isnull().sum().sort_values(ascending=False).head(20))
"
"""

# %% [markdown]
# #### Results:
# """
# Shape: (70962, 73)
#
# Columns: ['tract', 'State', 'County', 'RUCA_pri_cat', 'X_pop', 'X_sqmile', 'X_pop_dens', 'facilities', 'facilities_area', 'facilities_area_log', 'bs_25yo', 'time2work', 'crime_index', 'ln_crime_index', 'education', 'education_area', 'education_area.1', 'education_area_log', 'food_ratio', 'mean_drought', 'nindex_open', 'nata_sum', 'nata_sum_ln', 'ozone', 'pm25', 'pest', 'ln_pest', 'poverty', 'ln_poverty', 'rent_income_pct', 'selfservice', 'ln_selfservice', 'unemployment', 'ln_unemployment', 'OverallEQI', 'RUCA1_EQI', 'RUCA2_EQI', 'RUCA3_EQI', 'RUCA4_EQI', 'RUCA5_EQI', 'tract_fips', 'StateAbbr', 'StateDesc', 'CountyName', 'CountyFIPS', 'PLACES_ACCESS2', 'PLACES_ARTHRITIS', 'PLACES_BINGE', 'PLACES_BPHIGH', 'PLACES_BPMED', 'PLACES_CANCER', 'PLACES_CASTHMA', 'PLACES_CERVICAL', 'PLACES_CHD', 'PLACES_CHECKUP', 'PLACES_CHOLSCREEN', 'PLACES_COLON_SCREEN', 'PLACES_COPD', 'PLACES_COREM', 'PLACES_COREW', 'PLACES_CSMOKING', 'PLACES_DENTAL', 'PLACES_DIABETES', 'PLACES_HIGHCHOL', 'PLACES_KIDNEY', 'PLACES_LPA', 'PLACES_MAMMOUSE', 'PLACES_MHLTH', 'PLACES_OBESITY', 'PLACES_PHLTH', 'PLACES_SLEEP', 'PLACES_STROKE', 'PLACES_TEETHLOST']
# """
# """
# Missing values:
# RUCA5_EQI              67911
# RUCA4_EQI              67682
# RUCA2_EQI              64294
# RUCA3_EQI              63826
# RUCA1_EQI              20135
# PLACES_COREM              54
# PLACES_COREW              44
# PLACES_TEETHLOST          27
# PLACES_MAMMOUSE            7
# PLACES_COLON_SCREEN        3
# facilities_area            0
# CountyName                 0
# CountyFIPS                 0
# PLACES_ACCESS2             0
# PLACES_ARTHRITIS           0
# PLACES_BINGE               0
# PLACES_BPHIGH              0
# PLACES_BPMED               0
# PLACES_CANCER              0
# PLACES_CASTHMA             0
# """
